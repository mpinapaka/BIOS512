# %% [markdown]
# # ECDF (Empirical Cumulative Density Function)

# %%
library('tidyverse')
# Out:
# ── Attaching packages ─────────────────────────────────────── tidyverse 1.3.1 ──
#
# ✔ ggplot2 3.3.5     ✔ purrr   0.3.4
# ✔ tibble  3.1.5     ✔ dplyr   1.0.7
# ✔ tidyr   1.1.4     ✔ stringr 1.4.0
# ✔ readr   2.0.2     ✔ forcats 0.5.1
#
# ── Conflicts ────────────────────────────────────────── tidyverse_conflicts() ──
# ✖ dplyr::filter() masks stats::filter()
# ✖ dplyr::lag()    masks stats::lag()

# %%
options(repr.plot.res = 300, repr.plot.height = 3, repr.plot.width = 4)

p = ggplot(diamonds, aes(x = price))

p = p + geom_histogram(bins = 50)

p
# Out:
# plot without title

# %% [markdown]
# - What's the median?
# - What's the interquartile range?

# %%
diamonds |>
    summarize (min_price = min(price))
# Out:
#   min_price
# 1 326

# %%
diamonds|> summarize (max_price = max(price))
# Out:
#   max_price
# 1 18823

# %%
library ('patchwork')

# %%
options(repr.plot.res = 300, repr.plot.height = 3, repr.plot.width = 4)

p2 = ggplot(diamonds, aes(x = price))

p2 = p2 + stat_ecdf(geom = "point", size = 0.05, alpha = 0.5)

p2 = p2 + geom_hline(aes(yintercept = 0.50), color = 'orange')
p2 = p2 + geom_hline(aes(yintercept = 0.25), color = 'blue')
p2 = p2 + geom_hline(aes(yintercept = 0.75), color = 'red')

p2
# Out:
# plot without title

# %% [markdown]
# - What's the median?
# - What's the interquartile range?

# %%
p + p2 + plot_layout(ncol = 1)
# Out:
# plot without title
