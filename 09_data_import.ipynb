# %%
library('tidyverse')
# Out:
# ── Attaching packages ─────────────────────────────────────── tidyverse 1.3.1 ──
#
# ✔ ggplot2 3.3.5     ✔ purrr   0.3.4
# ✔ tibble  3.1.5     ✔ dplyr   1.0.7
# ✔ tidyr   1.1.4     ✔ stringr 1.4.0
# ✔ readr   2.0.2     ✔ forcats 0.5.1
#
# ── Conflicts ────────────────────────────────────────── tidyverse_conflicts() ──
# ✖ dplyr::filter() masks stats::filter()
# ✖ dplyr::lag()    masks stats::lag()

# %% [markdown]
# Import the 🦸🏾‍♀️"Avengers"🦹🏻 data from the [FiveThirtyEight data repository on GitHub](https://github.com/fivethirtyeight/data/blob/master/avengers/avengers.csv).

# %%
avengers_data = read_csv(
    'https://raw.githubusercontent.com/fivethirtyeight/data/master/avengers/avengers.csv',
    col_types = cols()
)

# %%
avengers_data |> head()
# Out:
#   URL
# 1 http://marvel.wikia.com/Henry_Pym_(Earth-616)
# 2 http://marvel.wikia.com/Janet_van_Dyne_(Earth-616)
# 3 http://marvel.wikia.com/Anthony_Stark_(Earth-616)
# 4 http://marvel.wikia.com/Robert_Bruce_Banner_(Earth-616)
# 5 http://marvel.wikia.com/Thor_Odinson_(Earth-616)
# 6 http://marvel.wikia.com/Richard_Jones_(Earth-616)
#   Name/Alias                  Appearances Current? Gender Probationary Introl
# 1 Henry Jonathan "Hank" Pym   1269        YES      MALE   NA
# 2 Janet van Dyne              1165        YES      FEMALE NA
# 3 Anthony Edward "Tony" Stark 3068        YES      MALE   NA
# 4 Robert Bruce Banner         2089        YES      MALE   NA
# 5 Thor Odinson                2402        YES      MALE   NA
# 6 Richard Milhouse Jones       612        YES      MALE   NA
#   Full/Reserve Avengers Intro Year Years since joining Honorary ⋯ Return1
# 1 Sep-63                      1963 52                  Full     ⋯ NO
# 2 Sep-63                      1963 52                  Full     ⋯ YES
# 3 Sep-63                      1963 52                  Full     ⋯ YES
# 4 Sep-63                      1963 52                  Full     ⋯ YES
# 5 Sep-63                      1963 52                  Full     ⋯ YES
# 6 Sep-63                      1963 52                  Honorary ⋯ NA
#   Death2 Return2 Death3 Return3 Death4 Return4 Death5 Return5
# 1 NA     NA      NA     NA      NA     NA      NA     NA
# 2 NA     NA      NA     NA      NA     NA      NA     NA
# 3 NA     NA      NA     NA      NA     NA      NA     NA
# 4 NA     NA      NA     NA      NA     NA      NA     NA
# 5 YES    NO      NA     NA      NA     NA      NA     NA
# 6 NA     NA      NA     NA      NA     NA      NA     NA
#   Notes
# 1 Merged with Ultron in Rage of Ultron Vol. 1. A funeral was held.
# 2 Dies in Secret Invasion V1:I8. Actually was sent tto Microverse later recovered
# 3 Death: "Later while under the influence of Immortus Stark committed a number of horrible acts and was killed.'  This set up young Tony. Franklin Richards later brought him back
# 4 Dies in Ghosts of the Future arc. However "he had actually used a hidden Pantheon base to survive"
# 5 Dies in Fear Itself brought back because that's kind of the whole point. Second death in Time Runs Out has not yet returned
# 6 NA

# %% [markdown]
# Make an ECDF plot 📊 of `Appearances`.

# %% [markdown]
# (❗️Hint: combine `arrange`, `mutate` and `row_number`/`rank` to produce a new column to encode with y-position.)

# %%
avengers_data |>
    select(`Name/Alias`, Appearances) |>
    arrange(Appearances) |> 
    mutate(rk = row_number() / n())
# Out:
#     Name/Alias                     Appearances rk
# 1   Moira Brandon                   2          0.005780347
# 2   Fiona                           2          0.011560694
# 3   Doug Taggert                    3          0.017341040
# 4   Gene Lorrene                    4          0.023121387
# 5   Dennis Sykes                    6          0.028901734
# 6   NA                              7          0.034682081
# 7   Monica Chang                   12          0.040462428
# 8   Alexis                         13          0.046242775
# 9   NA                             14          0.052023121
# 10  NA                             16          0.057803468
# 11  "Giulietta Nefaria"            18          0.063583815
# 12  Taki Matsuya                   18          0.069364162
# 13  NA                             22          0.075144509
# 14  Yvette                         22          0.080924855
# 15  America Chavez                 22          0.086705202
# 16  Nathaniel Richards             23          0.092485549
# 17  Kelsey Leigh Shorr             24          0.098265896
# 18  NA                             24          0.104046243
# 19  NA                             25          0.109826590
# 20  Emery Schaub                   26          0.115606936
# 21  Anthony Edward Stark           27          0.121387283
# 22  NA                             28          0.127167630
# 23  Adam Brashear                  29          0.132947977
# 24  DeMarr Davis                   31          0.138728324
# 25  Phillip Javert                 31          0.144508671
# 26  John Aman                      31          0.150289017
# 27  Craig Hollis                   33          0.156069364
# 28  Val Ventura                    34          0.161849711
# 29  Adam                           35          0.167630058
# 30  Kaluu                          35          0.173410405
# ⋮   ⋮                              ⋮           ⋮
# 144 Samuel Guthrie                  679        0.8323699
# 145 Simon Williams                  692        0.8381503
# 146 Heracles                        741        0.8439306
# 147 Flash Thompson                  746        0.8497110
# 148 Pietro Maximoff                 769        0.8554913
# 149 T'Challa                        780        0.8612717
# 150 Anna Marie                      877        0.8670520
# 151 Carl Lucas                      886        0.8728324
# 152 Jennifer Walters                933        0.8786127
# 153 Carol Susan Jane Danvers        935        0.8843931
# 154 Victor Shade (alias)           1036        0.8901734
# 155 Natalia Alianovna Romanova     1112        0.8959538
# 156 Janet van Dyne                 1165        0.9017341
# 157 Wanda Maximoff                 1214        0.9075145
# 158 Henry Jonathan "Hank" Pym      1269        0.9132948
# 159 Doctor Stephen Vincent Strange 1324        0.9190751
# 160 Matt Murdock                   1375        0.9248555
# 161 Clinton Francis Barton         1456        0.9306358
# 162 Namor McKenzie                 1561        0.9364162
# 163 Ororo Munroe                   1598        0.9421965
# 164 Susan Richards (nee Storm)     1761        0.9479769
# 165 Henry P. McCoy                 1886        0.9537572
# 166 Robert Bruce Banner            2089        0.9595376
# 167 Reed Richards                  2125        0.9653179
# 168 Benjamin Jacob Grimm           2305        0.9710983
# 169 Thor Odinson                   2402        0.9768786
# 170 Anthony Edward "Tony" Stark    3068        0.9826590
# 171 James "Logan" Howlett          3130        0.9884393
# 172 Steven Rogers                  3458        0.9942197
# 173 Peter Benjamin Parker          4333        1.0000000
