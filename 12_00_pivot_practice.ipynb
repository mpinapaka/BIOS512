# %% [markdown]
# Load the `tidyverse` and the 🐧`palmerpenguins`🐧 packages.

# %%
library ('tidyverse')
library ('palmerpenguins')
# Out:
# ── Attaching packages ─────────────────────────────────────── tidyverse 1.3.2 ──
# ✔ ggplot2 3.4.0      ✔ purrr   0.3.5
# ✔ tibble  3.1.8      ✔ dplyr   1.0.10
# ✔ tidyr   1.2.1      ✔ stringr 1.4.1
# ✔ readr   2.1.3      ✔ forcats 0.5.2
# ── Conflicts ────────────────────────────────────────── tidyverse_conflicts() ──
# ✖ dplyr::filter() masks stats::filter()
# ✖ dplyr::lag()    masks stats::lag()

# %% [markdown]
# We want to make a jitter chart of normalized penguin length measurements (e.g. `bill_depth_mm`).

# %% [markdown]
# Like this:

# %% [markdown]
# ![](https://github.com/chuckpr/BIOS512/blob/main/in-class-exercises/12/12_00_pivot_chart.png?raw=true)

# %% [markdown]
# ...but our data is not in the right "shape."

# %% [markdown]
# Use `pivot_longer` to re-shape the data to create the chart above 👆.
#
# Then, calculate a normalized value for each measurement by dividing *individual measurement values* by the *maximum value* within the measurement type (e.g. `bill_depth_mm` is a "measurement type") and capture this new value in a new column with `mutate`.

# %%
penguins |> head()
# Out:
#   species island    bill_length_mm bill_depth_mm flipper_length_mm body_mass_g
# 1 Adelie  Torgersen 39.1           18.7          181               3750
# 2 Adelie  Torgersen 39.5           17.4          186               3800
# 3 Adelie  Torgersen 40.3           18.0          195               3250
# 4 Adelie  Torgersen   NA             NA           NA                 NA
# 5 Adelie  Torgersen 36.7           19.3          193               3450
# 6 Adelie  Torgersen 39.3           20.6          190               3650
#   sex    year
# 1 male   2007
# 2 female 2007
# 3 female 2007
# 4 NA     2007
# 5 female 2007
# 6 male   2007

# %%
penguins |> 
    pivot_longer(c(bill_length_mm, bill_depth_mm, flipper_length_mm)) |>
    group_by(name) |>
    mutate(value_normalized = value / max(value, na.rm = TRUE))
# Out:
#      species   island    body_mass_g sex    year name              value
# 1    Adelie    Torgersen 3750        male   2007 bill_length_mm     39.1
# 2    Adelie    Torgersen 3750        male   2007 bill_depth_mm      18.7
# 3    Adelie    Torgersen 3750        male   2007 flipper_length_mm 181.0
# 4    Adelie    Torgersen 3800        female 2007 bill_length_mm     39.5
# 5    Adelie    Torgersen 3800        female 2007 bill_depth_mm      17.4
# 6    Adelie    Torgersen 3800        female 2007 flipper_length_mm 186.0
# 7    Adelie    Torgersen 3250        female 2007 bill_length_mm     40.3
# 8    Adelie    Torgersen 3250        female 2007 bill_depth_mm      18.0
# 9    Adelie    Torgersen 3250        female 2007 flipper_length_mm 195.0
# 10   Adelie    Torgersen   NA        NA     2007 bill_length_mm       NA
# 11   Adelie    Torgersen   NA        NA     2007 bill_depth_mm        NA
# 12   Adelie    Torgersen   NA        NA     2007 flipper_length_mm    NA
# 13   Adelie    Torgersen 3450        female 2007 bill_length_mm     36.7
# 14   Adelie    Torgersen 3450        female 2007 bill_depth_mm      19.3
# 15   Adelie    Torgersen 3450        female 2007 flipper_length_mm 193.0
# 16   Adelie    Torgersen 3650        male   2007 bill_length_mm     39.3
# 17   Adelie    Torgersen 3650        male   2007 bill_depth_mm      20.6
# 18   Adelie    Torgersen 3650        male   2007 flipper_length_mm 190.0
# 19   Adelie    Torgersen 3625        female 2007 bill_length_mm     38.9
# 20   Adelie    Torgersen 3625        female 2007 bill_depth_mm      17.8
# 21   Adelie    Torgersen 3625        female 2007 flipper_length_mm 181.0
# 22   Adelie    Torgersen 4675        male   2007 bill_length_mm     39.2
# 23   Adelie    Torgersen 4675        male   2007 bill_depth_mm      19.6
# 24   Adelie    Torgersen 4675        male   2007 flipper_length_mm 195.0
# 25   Adelie    Torgersen 3475        NA     2007 bill_length_mm     34.1
# 26   Adelie    Torgersen 3475        NA     2007 bill_depth_mm      18.1
# 27   Adelie    Torgersen 3475        NA     2007 flipper_length_mm 193.0
# 28   Adelie    Torgersen 4250        NA     2007 bill_length_mm     42.0
# 29   Adelie    Torgersen 4250        NA     2007 bill_depth_mm      20.2
# 30   Adelie    Torgersen 4250        NA     2007 flipper_length_mm 190.0
# ⋮    ⋮         ⋮         ⋮           ⋮      ⋮    ⋮                 ⋮
# 1003 Chinstrap Dream     3800        male   2009 bill_length_mm     50.2
# 1004 Chinstrap Dream     3800        male   2009 bill_depth_mm      18.8
# 1005 Chinstrap Dream     3800        male   2009 flipper_length_mm 202.0
# 1006 Chinstrap Dream     3525        female 2009 bill_length_mm     45.6
# 1007 Chinstrap Dream     3525        female 2009 bill_depth_mm      19.4
# 1008 Chinstrap Dream     3525        female 2009 flipper_length_mm 194.0
# 1009 Chinstrap Dream     3950        male   2009 bill_length_mm     51.9
# 1010 Chinstrap Dream     3950        male   2009 bill_depth_mm      19.5
# 1011 Chinstrap Dream     3950        male   2009 flipper_length_mm 206.0
# 1012 Chinstrap Dream     3650        female 2009 bill_length_mm     46.8
# 1013 Chinstrap Dream     3650        female 2009 bill_depth_mm      16.5
# 1014 Chinstrap Dream     3650        female 2009 flipper_length_mm 189.0
# 1015 Chinstrap Dream     3650        female 2009 bill_length_mm     45.7
# 1016 Chinstrap Dream     3650        female 2009 bill_depth_mm      17.0
# 1017 Chinstrap Dream     3650        female 2009 flipper_length_mm 195.0
# 1018 Chinstrap Dream     4000        male   2009 bill_length_mm     55.8
# 1019 Chinstrap Dream     4000        male   2009 bill_depth_mm      19.8
# 1020 Chinstrap Dream     4000        male   2009 flipper_length_mm 207.0
# 1021 Chinstrap Dream     3400        female 2009 bill_length_mm     43.5
# 1022 Chinstrap Dream     3400        female 2009 bill_depth_mm      18.1
# 1023 Chinstrap Dream     3400        female 2009 flipper_length_mm 202.0
# 1024 Chinstrap Dream     3775        male   2009 bill_length_mm     49.6
# 1025 Chinstrap Dream     3775        male   2009 bill_depth_mm      18.2
# 1026 Chinstrap Dream     3775        male   2009 flipper_length_mm 193.0
# 1027 Chinstrap Dream     4100        male   2009 bill_length_mm     50.8
# 1028 Chinstrap Dream     4100        male   2009 bill_depth_mm      19.0
# 1029 Chinstrap Dream     4100        male   2009 flipper_length_mm 210.0
# 1030 Chinstrap Dream     3775        female 2009 bill_length_mm     50.2
# 1031 Chinstrap Dream     3775        female 2009 bill_depth_mm      18.7
# 1032 Chinstrap Dream     3775        female 2009 flipper_length_mm 198.0
#      value_normalized
# 1    0.6560403
# 2    0.8697674
# 3    0.7835498
# 4    0.6627517
# 5    0.8093023
# 6    0.8051948
# 7    0.6761745
# 8    0.8372093
# 9    0.8441558
# 10          NA
# 11          NA
# 12          NA
# 13   0.6157718
# 14   0.8976744
# 15   0.8354978
# 16   0.6593960
# 17   0.9581395
# 18   0.8225108
# 19   0.6526846
# 20   0.8279070
# 21   0.7835498
# 22   0.6577181
# 23   0.9116279
# 24   0.8441558
# 25   0.5721477
# 26   0.8418605
# 27   0.8354978
# 28   0.7046980
# 29   0.9395349
# 30   0.8225108
# ⋮    ⋮
# 1003 0.8422819
# 1004 0.8744186
# 1005 0.8744589
# 1006 0.7651007
# 1007 0.9023256
# 1008 0.8398268
# 1009 0.8708054
# 1010 0.9069767
# 1011 0.8917749
# 1012 0.7852349
# 1013 0.7674419
# 1014 0.8181818
# 1015 0.7667785
# 1016 0.7906977
# 1017 0.8441558
# 1018 0.9362416
# 1019 0.9209302
# 1020 0.8961039
# 1021 0.7298658
# 1022 0.8418605
# 1023 0.8744589
# 1024 0.8322148
# 1025 0.8465116
# 1026 0.8354978
# 1027 0.8523490
# 1028 0.8837209
# 1029 0.9090909
# 1030 0.8422819
# 1031 0.8697674
# 1032 0.8571429

# %%
options(repr.plot.width = 8)

penguins2 = penguins |> 
    pivot_longer(c(bill_length_mm, bill_depth_mm, flipper_length_mm)) |>
    group_by(name) |>
    mutate(value_normalized = value / max(value, na.rm = TRUE))


p = ggplot(penguins2, aes(x = value_normalized, y = name, color = species)) + 
    geom_point(position = position_jitter(height = 0.3, width = 0), alpha = 0.45, na.rm = T) +
    scale_color_brewer(palette = 'Set2')

p
# Out:
# plot without title

# %% [markdown]
# Now make the chart.
